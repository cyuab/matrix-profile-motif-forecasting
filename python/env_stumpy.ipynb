# %%
import os
# Must be set before importing libraries that use the GPU!
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
os.environ["CUDA_VISIBLE_DEVICES"] = "6" # Example: Only expose the RTX 5880 (Index 6)

# %%
import stumpy
import numpy as np

# Create dummy data
T = np.random.rand(10000)
m = 50

# %%
# Run on specific GPU (e.g., device_id=6 for the RTX 5880 Ada based on your list)
mps = stumpy.gpu_stump(T, m)

# %%
import datetime

print(f"This notebook was last run end-to-end on: {datetime.datetime.now()}\n")
###
###
###
# Out:
# This notebook was last run end-to-end on: 2026-01-15 12:14:35.683019
