# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import xgboost as xgb
import sklearn
import stumpy

# %%
packages = {
    "Python": sys.version.split()[0],
    "pandas": pd.__version__,
    "numpy": np.__version__,
    "matplotlib": matplotlib.__version__,
    "seaborn": sns.__version__,
    "xgboost": xgb.__version__,
    "scikit-learn": sklearn.__version__,
    "stumpy": stumpy.__version__
}

# %% [markdown]
# # Session Information

# %%
pd.DataFrame(list(packages.items()), columns=["Package", "Version"])
# Out:
#         Package  Version
# 0        Python  3.10.18
# 1        pandas    2.3.1
# 2         numpy    2.2.6
# 3    matplotlib   3.10.5
# 4       seaborn   0.13.2
# 5       xgboost    3.0.3
# 6  scikit-learn    1.7.1
# 7        stumpy   1.13.0

# %%
import datetime

print(f"This notebook was last run end-to-end on: {datetime.datetime.now()}\n")
###
###
###
# Out:
# This notebook was last run end-to-end on: 2025-12-26 21:21:56.984315
